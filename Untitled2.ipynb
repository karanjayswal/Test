# %% [markdown]
# <a href="https://colab.research.google.com/github/karanjayswal/Test/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f2d3136-5968-4874-9c07-cb32a2b5f279" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f2d3136-5968-4874-9c07-cb32a2b5f279">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Analysis.txt to Analysis.txt

# %%
file_name = "Analysis.txt"
uploaded[file_name].decode("utf-8")

data = uploaded[file_name].decode("utf-8").split("\n")

# %%
d = []
for i in data:
  d.append(i.split('\t'))
# d

# %%
s1 = []
for i in range(len(d)):
  for j in range(len(d[i])):
    s = d[i][j].split(' ')
    s1.append(d[i][j].split('\t'))
    # print(s1)
    # print
    # if s[0]=='Frame':
    #   print(d[i][j])

# %%
names = []
emotions = []
for i in range(len(s1)):
  for j in range(len(s1[i])):
      try:
        if s1[i][0][0]=='n':
          names.append(s1[i][j].split(':')[1])
        if s1[i][0][0]=='S':
          emotions.append(s1[i][j].split(':')[1])
      except:
        continue

# %%
# print('Names'+' '+'Emotion')
# for i in range(len(names)):

#   print(names[i]+' '+emotions[i])

# %%
import re
for i in range(len(names)):
  names[i] = re.sub(r"[^a-zA-Z' ']","",names[i])
  names[i] = names[i].lstrip()
  names[i] = names[i].rstrip()

# %%
unique_names = set(names)

# %%
len(unique_names)
# Out:
# 276

# %%
merge=[]
for i in range(len(names)):
  temp=[]
  temp.append(names[i])
  temp.append(emotions[i])
  merge.append(temp)
# merge

# %%
import pandas as pd
dict = {'name': names, 'emotion': emotions}	
df = pd.DataFrame(dict)
df.to_csv('names.csv')
df
# Out:
#                            name  emotion
# 0     eset iceerl bikkyl leskle  neutral
# 1                 NiteshAfahari      sad
# 2                aseivris eanal      sad
# 3                  HARSH SHARMA  neutral
# 4                    Harsch Rai  neutral
# ...                         ...      ...
# 1007                 Sagar cies    happy
# 1008                        rey  neutral
# 1009                 Sangam ele      sad
# 1010              Shivam  Singh  neutral
# 1011                    i llast     fear
#
# [1012 rows x 2 columns]

# %%
unique_emotions = set(emotions)

# %%
unique_emotions  = list(unique_emotions)
unique_emotions
unique_names  = list(unique_names)

# %%
count_emotion = []
for i in range(len(unique_emotions)):
  # print(unique_emotions[i])
  count=0
  for j in range(len(emotions)):
    if unique_emotions[i]==emotions[j]:
      count=count+1
  count_emotion.append(count)

# %%
count_emotion
# Out:
# [106, 4, 184, 35, 46, 637]

# %%
dict = {'emotion': unique_emotions,'count':count_emotion}	
dfc = pd.DataFrame(dict)
dfc.to_csv('count.csv')
dfc
# Out:
#     emotion  count
# 0       sad    106
# 1  surprise      4
# 2     happy    184
# 3      fear     35
# 4     angry     46
# 5   neutral    637

# %%
import plotly.express as px

df = px.data.tips()
fig = px.pie(dfc, values='count', names='emotion')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
count_names = []
for i in range(len(unique_names)):
  # print(unique_emotions[i])
  count=0
  for j in range(len(names)):
    if unique_names[i]==names[j]:
      count=count+1
  count_names.append(count)

# %%
dict = {'name': unique_names,'count':count_names}	
dfn = pd.DataFrame(dict)
dfn.to_csv('count.csv')
dfn
# Out:
#                        name  count
# 0                               90
# 1                       rey      6
# 2               Pooja Yadav     26
# 3            welatelal  may      1
# 4        Manich  alles t om      4
# ..                      ...    ...
# 271   Malahcincle ase Ss lU      1
# 272         Nanani SI seial      3
# 273  Kumar Soni Aditya rele      3
# 274           Nanani SI hah      3
# 275            HARSH SHARMA      8
#
# [276 rows x 2 columns]

# %%
search_names=[]
for i in range(len(count_names)):
    search_names.append(unique_names[i])

# %%
name_emotion=[]
for i in range(len(search_names)):
  name_s=search_names[i]
  temp=[]
  for j in range(len(names)):
    if(name_s==names[j]):
      temp.append(emotions[j])
  name_emotion.append(temp)

# %%
name_emotion
# Out:
# [['neutral',
#   'neutral',
#   'sad',
#   'neutral',
#   'neutral',
#   'sad',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
#   'sad',
#   'neutral',
#   'neutral',
#   'sad',
#   'neutral',
#   'neutral',
#   'sad',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'sad',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
#   'neutral',
#   'sad',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
#   'neutral',
#   'sad',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
#   'happy',
#   'neutral',
#   'happy',
#   'neutral',
#   'neutral',
# ...

# %%
dict = {'name_search': search_names,'Emotions':name_emotion}	
dfne = pd.DataFrame(dict)
dfne.to_csv('name_emotion.csv')
dfne
# Out:
#                 name_search                                           Emotions
# 0                            [neutral, neutral, sad, neutral, neutral, sad,...
# 1                       rey  [neutral, neutral, neutral, neutral, neutral, ...
# 2               Pooja Yadav  [neutral, neutral, neutral, neutral, neutral, ...
# 3            welatelal  may                                            [angry]
# 4        Manich  alles t om               [neutral, neutral, neutral, neutral]
# ..                      ...                                                ...
# 271   Malahcincle ase Ss lU                                          [neutral]
# 272         Nanani SI seial                        [neutral, neutral, neutral]
# 273  Kumar Soni Aditya rele                                 [fear, fear, fear]
# 274           Nanani SI hah                        [neutral, neutral, neutral]
# 275            HARSH SHARMA  [neutral, neutral, neutral, neutral, neutral, ...
#
# [276 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# surprise 	4
# 1 	fear 	35
# 2 	neutral 	637
# 3 	sad 	106
# 4 	angry 	46
# 5 	happy 	
y_axis=[]
for i in range(len(name_emotion)):
  temp=[]
  for j in range(len(name_emotion[i])):
    if name_emotion[i][j]=='surprise':
      temp.append(0)
    elif name_emotion[i][j]=='fear':
      temp.append(1)
    elif name_emotion[i][j]=='neutral':
      temp.append(2)
    elif name_emotion[i][j]=='sad':
      temp.append(3)
    elif name_emotion[i][j]=='angry':
      temp.append(4)
    elif name_emotion[i][j]=='happy':
      temp.append(5)
  y_axis.append(temp)

# %%
len(y_axis[4])
# Out:
# 4

# %%
import matplotlib.pyplot as plt
for i in range(len(search_names)):
  x = list(range(1, len(y_axis[i])+1))
  # corresponding y axis values
  #y = []
  y=y_axis[i]
  # plotting the points 
    

  plt.plot(x,y)
  # set tick positions, adjust label text
  plt.yticks(y,name_emotion[i])
  plt.xlabel('Frames')
  plt.ylabel('Emotions')
  plt.margins(x=0,y=0.1)

  plt.title(search_names[i])
  plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# k=1
# for i in range(len(search_names)):
#   x = list(range(1, len(y_axis[i])+1))
#   # corresponding y axis values
#   #y = []
#   y=y_axis[i]
#   plt.subplot(2, 3, k)
#   plt.plot(x,y)
#   k=k+1
#   plt.yticks(y,name_emotion[i])
#   plt.xlabel('Frames')
#   plt.ylabel('Emotions')
#   plt.margins(x=0,y=0.1)
#   if k>7:
#     k=1
# plt.subplots_adjust(left=0.2,
#                     bottom=0.2, 
#                     right=2, 
#                     top=2.5, 
#                     wspace=0.5, 
#                     hspace=0.5)
# plt.show()

# %%
# import matplotlib.pyplot as plt
# l=0
# for i in range(len(search_names)):
#   l = l+1
#   x = list(range(1, len(y_axis[i])+1))
#   # corresponding y axis values
#   #y = []
#   y=y_axis[i]
#   # plotting the points 
#   #plt.rcParams["figure.figsize"] = [10.00, 3.50]
#   #plt.rcParams["figure.autolayout"] = True

#   plt.subplot(4, 2, l)

#   # set tick positions, adjust label text
#   plt.yticks(y,name_emotion[i])
#   plt.xlabel('Frames')
#   plt.ylabel('Emotions')
#   plt.margins(x=0,y=0.1)

#   plt.title(search_names[i])
#   plt.plot(x,y)
#   plt.subplots_adjust(left=0.2,
#                     bottom=0.2, 
#                     right=2.0, 
#                     top=2.5, 
#                     wspace=0.5, 
#                     hspace=0.5)
# plt.show()

# %%
import plotly.graph_objs as go
from plotly.offline import iplot
# from plotly.offline import plot, init_notebook_mode
# init_notebook_mode(connected=True)

# %%
s_name=[]
e_name=[]
# for i in range(len(search_names)):
# name_emotion[1]
for i in range(len(name_emotion)):
  if(len(list(set(name_emotion[i])))>1):
    s_name.append(search_names[i])
    e_name.append(name_emotion[i])

# %%
# print(len(list(set(name_emotion[2]))))
print(e_name[4])
# Out:
# ['fear', 'fear', 'fear', 'surprise', 'surprise']

# %%
y_axis=[]
for i in range(len(e_name)):
  temp=[]
  for j in range(len(e_name[i])):
    if e_name[i][j]=='surprise':
      temp.append(0)
    elif e_name[i][j]=='fear':
      temp.append(1)
    elif e_name[i][j]=='neutral':
      temp.append(2)
    elif e_name[i][j]=='sad':
      temp.append(3)
    elif e_name[i][j]=='angry':
      temp.append(4)
    elif e_name[i][j]=='happy':
      temp.append(5)
  y_axis.append(temp)

# %%
e_name[5]
# Out:
# ['sad', 'sad', 'angry', 'angry', 'angry', 'sad']

# %%
from plotly import tools
n = len(s_name)
i=0
while(i<n):
  try:
      fig = tools.make_subplots(rows = 1,cols = 1,subplot_titles = (s_name[i]," "))
      trace0 = go.Scatter(x = list(range(1, len(y_axis[i])+1)),y = e_name[i],mode = "lines",name = s_name[i])
      fig.append_trace(trace0, 1, 1)
      iplot(fig)
      i=i+1
  except:
    print(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from plotly import tools
n = len(s_name)
i=0
while(i<n):
  try:
    # x_axis = list(range(1, len(y_axis[i])+1))
    if i+1<n:
      fig = tools.make_subplots(rows = 1,cols = 2,subplot_titles = (s_name[i],s_name[i+1]))
      trace0 = go.Scatter(x = list(range(1, len(y_axis[i])+1)),y = e_name[i],mode = "lines",name = s_name[i])
      trace1 = go.Scatter(x = list(range(1, len(y_axis[i+1])+1)),y = e_name[i+1],mode = "lines",name = s_name[i+1])
      # print(e_name[i+1])
      fig.append_trace(trace0, 1, 1)
      fig.append_trace(trace1, 1, 2)
      iplot(fig)
      i=i+2
    else:
      fig = tools.make_subplots(rows = 1,cols = 2,subplot_titles=(s_name[i],""))
      trace0 = go.Scatter(x = list(range(1, len(y_axis[i])+1)),y = e_name[i],mode = "lines",name = s_name[i])
      fig.append_trace(trace0, 1, 1)
      iplot(fig)
      i=i+1
    
  except:
    print(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(len(y_axis))
print(len(e_name))
print(len(s_name))
# Out:
# 7
# 7
# 7

# %%
e_name[5]
# Out:
# ['sad', 'sad', 'angry', 'angry', 'angry', 'sad']

# %%
from plotly import tools
n = len(s_name)
i=0
while(i<n):
  try:
    x_axis = list(range(1, len(y_axis[i])+1))
    # if i+3<n:
    #   fig = tools.make_subplots(rows = 1,cols = 4,subplot_titles = (s_name[i],s_name[i+1],s_name[i+2],s_name[i+3]))
    #   trace0 = go.Scatter(x = x_axis,y = e_name[i],mode = "lines",name = s_name[i])
    #   trace1 = go.Scatter(x = x_axis,y = e_name[i+1],mode = "lines",name = s_name[i+1])
    #   trace2 = go.Scatter(x = x_axis,y = e_name[i+2],mode = "lines",name = s_name[i+2])
    #   trace3 = go.Scatter(x = x_axis,y = e_name[i+3],mode = "lines",name = s_name[i+3])
    #   fig.append_trace(trace0, 1, 1)
    #   fig.append_trace(trace1, 1, 2)
    #   fig.append_trace(trace2, 1, 3)
    #   fig.append_trace(trace3, 1, 4)      
    #   iplot(fig)
    #   i=i+4
      
    if i+2<n:
      fig = tools.make_subplots(rows = 1,cols = 3,subplot_titles = (s_name[i],s_name[i+1],s_name[i+2]))
      trace0 = go.Scatter(x = list(range(1, len(y_axis[i])+1)),y = e_name[i],mode = "lines",name = s_name[i])
      trace1 = go.Scatter(x = list(range(1, len(y_axis[i+1])+1)),y = e_name[i+1],mode = "lines",name = s_name[i+1])
      trace2 = go.Scatter(x = list(range(1, len(y_axis[i+2])+1)),y = e_name[i+2],mode = "lines",name = s_name[i+2])
      fig.append_trace(trace0, 1, 1)
      fig.append_trace(trace1, 1, 2)
      fig.append_trace(trace2, 1, 3)
      iplot(fig)
      i=i+3
    
    elif i+1<n:
      fig = tools.make_subplots(rows = 1,cols = 2,subplot_titles = (s_name[i],s_name[i+1]))
      trace0 = go.Scatter(x = list(range(1, len(y_axis[i])+1)),y = e_name[i],mode = "lines",name = s_name[i])
      trace1 = go.Scatter(x = list(range(1, len(y_axis[i+1])+1)),y = e_name[i+1],mode = "lines",name = s_name[i+1])
      fig.append_trace(trace0, 1, 1)
      fig.append_trace(trace1, 1, 2)
      iplot(fig)
      i=i+2

    else:
      fig = tools.make_subplots(rows = 1,cols = 2,subplot_titles=(s_name[i],""))
      trace0 = go.Scatter(x = list(range(1, len(y_axis[i])+1)),y = e_name[i],mode = "lines",name = s_name[i])
      fig.append_trace(trace0, 1, 1)
      iplot(fig)
      i=i+1
    
  except:
    print(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/tools.py:465: DeprecationWarning:
#
# plotly.tools.make_subplots is deprecated, please use plotly.subplots.make_subplots instead
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 8-June

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
i=0
fig = make_subplots(specs=[[{"secondary_y": True}]])
trace0 = go.Scatter(x = list(range(1, len(y_axis[i])+1)),y = e_name[i],mode = "lines",name = s_name[i])
trace1 = go.Scatter(x = list(range(1, len(y_axis[i+1])+1)),y = e_name[i+1],mode = "lines",name = s_name[i+1])
trace2 = go.Scatter(x = list(range(1, len(y_axis[i+2])+1)),y = e_name[i+2],mode = "lines",name = s_name[i+2])
fig.add_trace(trace0,secondary_y=True)
fig.add_trace(trace1,secondary_y=True)
fig.add_trace(trace2,secondary_y=True)

fig['layout'].update(height = 600, width = 800, title = "Graph",xaxis={'tickangle':-90})
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
i=0
fig = make_subplots(specs=[[{"secondary_y": True}]])
# print(n)
while i<n:
  trace0 = go.Scatter(x = list(range(1, len(y_axis[i])+1)),y = e_name[i],mode = "lines",name = s_name[i],)
  fig.add_trace(trace0,secondary_y=True)
  i=i+1

fig['layout'].update(title = "Graph of all students")
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# from jupyter_dash import JupyterDash
# import dash_html_components as html
# import pandas as pd
# import branca.colormap

# # Load Data
# df = pd.DataFrame([[j*10+i for i in range(10)] for j in range(10)])

# external_stylesheets = [{
#     'href': 'https://use.fontawesome.com/releases/v5.8.1/css/all.css',
#     'rel': 'stylesheet', 'crossorigin': 'anonymous',
#     'integrity': 'sha384-50oBUHEmvpQ+1lW4y57PTFmhCaXp0ML5d60M1M7uH2+nqUivzIebhndOJK28anvf',
#     }]

# # possibly could use a a different library for this - simple way to map a value to a colormap
# cm = branca.colormap.LinearColormap(["red","yellow","green"], vmin=0, vmax=100, caption=None)

# def mysmiley(v):
#     sm = ["far fa-grin", "far fa-smile", "far fa-meh", "far fa-frown"]
#     return html.Span(className=sm[3-(v//25)], style={"color":cm(v),"font-size": "2em"})

# # Build App
# app = JupyterDash(__name__, external_stylesheets=external_stylesheets)
# app.layout = html.Div([
#     html.Table([html.Tr([html.Td(mysmiley(c)) for c in r]) for r in df.values])
# ])

# # Run app and display result inline in the notebook
# app.run_server(mode='inline')

# %%
# pip install jupyter_dash
